# %% [markdown]
# <a href="https://colab.research.google.com/github/parkyonguon/Data-Analysis-with-Open-Source/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd

url = "http://openapi.seoul.go.kr:8088/444d734d6870617238365454656e4b/json/energyUseDataSummaryInfo/1/5/2024"

params = {
    'serviceKey': 'api_key',
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}
response = requests.get(url, params=params)

data=response.json()['energyUseDataSummaryInfo']['row']
df = pd.DataFrame(data)

df_rename = df.rename(columns={'YEAR':'년도','MM_TYPE':'사용처','EUS':'전기','GUS':'가스','WUS':'수도','HUS':'지역난방'})

selected_col = df_rename [['년도','사용처','전기','가스','수도','지역난방']]
selected_col
selected_col . to_json('energyUseData2024.json', indent=4 , force_ascii=False)
selected_col
# Out:
#      년도      사용처         전기        가스          수도         지역난방
# 0  2024     소상공인  101773064   2544825   1560686.6          360
# 1  2024       기업  633735769  30096486   4448777.4            0
# 2  2024       개인  134828126  42103424   7326853.6  1513199.277
# 3  2024     공공기관  152992881   3814815      896842            0
# 4  2024  공동주택관리소  548480228   8221238  20262147.7            0
