# %% [markdown]
# <a href="https://colab.research.google.com/github/parkyonguon/Data-Analysis-with-Open-Source/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
response.json()
# Out:
# {'energyUseDataSummaryInfo': {'list_total_count': 84,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'YEAR': '2015',
#     'MON': '12',
#     'MM_TYPE': '학교',
#     'CNT': '4142',
#     'EUS': '129747032',
#     'EUS1': '142880159',
#     'EUS2': '138232678',
#     'ECO2_1': '-10809386.5',
#     'ECO2_2': '-4583179.876',
#     'GUS': '7146196',
#     'GUS1': '8370038',
#     'GUS2': '8426789',
#     'GCO2_1': '-1252217.5',
#     'GCO2_2': '-2804967.2',
#     'WUS': '2243488.6',
#     'WUS1': '2288624.2',
#     'WUS2': '2348669.6',
#     'WCO2_1': '-75158.3',
#     'WCO2_2': '-24952.5556',
#     'HUS': '1431',
#     'HUS1': '1946',
#     'HUS2': '1858',
#     'HCO2_1': '-471',
#     'HCO2_2': '-1875.522',
#     'REG_DATE': '2016-03-05 04:00:01.0'},
#    {'YEAR': '2015',
#     'MON': '12',
#     'MM_TYPE': '개인',
#     'CNT': '852483',
#     'EUS': '203388142',
#     'EUS1': '209110435',
#     'EUS2': '210601335',
#     'ECO2_1': '-6467743',
# ...

# %%
import requests
import json
url = "http://openapi.seoul.go.kr:8088/444d734d6870617238365454656e4b/json/energyUseDataSummaryInfo/1/5/2016"

params = {
    'serviceKey': 'api_key',
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}
response = requests.get(url, params=params)

if response.status_code == 200:
    print("api 호출 성공")
    print(response.json())
else:
    print(f"API 호출 실패: {response.status_code}")
# Out:
# api 호출 성공
# ...

# %%
import pandas as pd
data=response.json()['energyUseDataSummaryInfo']['row']
df = pd.DataFrame(data)
df.to_json('energyUseData2015.json', indent=4 , force_ascii=False)

# %%
import pandas as pd
data=response.json()['energyUseDataSummaryInfo']['row']
df = pd.DataFrame(data)

df_rename = df.rename(columns={'YEAR':'년도','MM_TYPE':'사용처','EUS':'전기','GUS':'가스','WUS':'수도','HUS':'지역난방'})

selected_col = df_rename [['년도','사용처','전기','가스','수도','지역난방']]
selected_col
# Out:
#      년도      사용처         전기        가스            수도          지역난방
# 0  2016     공공기관  134491611   3799390     1009037.4             0
# 1  2016     종교단체    4622720    327872         43298             0
# 2  2016       개인  212192127  46917377  14415082.726  17554645.961
# 3  2016     소상공인   45392360   3295290     1269606.8         1.588
# 4  2016  공동주택관리소  309956930  11459582    14331506.6             0

# %%
response.json()
# Out:
# {'energyUseDataSummaryInfo': {'list_total_count': 84,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'YEAR': '2015',
#     'MON': '12',
#     'MM_TYPE': '학교',
#     'CNT': '4142',
#     'EUS': '129747032',
#     'EUS1': '142880159',
#     'EUS2': '138232678',
#     'ECO2_1': '-10809386.5',
#     'ECO2_2': '-4583179.876',
#     'GUS': '7146196',
#     'GUS1': '8370038',
#     'GUS2': '8426789',
#     'GCO2_1': '-1252217.5',
#     'GCO2_2': '-2804967.2',
#     'WUS': '2243488.6',
#     'WUS1': '2288624.2',
#     'WUS2': '2348669.6',
#     'WCO2_1': '-75158.3',
#     'WCO2_2': '-24952.5556',
#     'HUS': '1431',
#     'HUS1': '1946',
#     'HUS2': '1858',
#     'HCO2_1': '-471',
#     'HCO2_2': '-1875.522',
#     'REG_DATE': '2016-03-05 04:00:01.0'},
#    {'YEAR': '2015',
#     'MON': '12',
#     'MM_TYPE': '개인',
#     'CNT': '852483',
#     'EUS': '203388142',
#     'EUS1': '209110435',
#     'EUS2': '210601335',
#     'ECO2_1': '-6467743',
# ...
